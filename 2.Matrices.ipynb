# %% [markdown]
# <h2><center> Deriving the Preference and Confidence Matrices </center></h2>

# %% [markdown]
# In the regular recommender system case with explicit data we deal with a single entity - *the ratings matrix*. When implicit data is used, we might have something like clicks, views, playtime, viewtime, etc. In our demo, we will have a *playtime matrix* which specifies the number of hours each user has played each game.
#
# The researchers from AT&T suggest deriving two new tables from the *playtime matrix* - the *confidence matrix* and the *preference matrix*.
#
# The *preference matrix* is a binary matrix which encodes whether a given user likes a particular item. Basically, if you've bought or played a game, we assume you like it.
# The *confidence matrix* is a floating point matrix which encodes how confident we are that you actually like or dislike the game. Basically, the more you play, the more confident we are.

# %%
import pandas as pd
import json
from collections import Counter
from IPython.core.display import display, HTML

DATA_DIR = "data_dir/train-test-split-v2.json"
#display(HTML("<style>.container { width:90% !important; }</style>"))

# %%
data = pd.read_json(DATA_DIR, lines=True,dtype={'steam_id':str})
data.head()
# Out:
#             steam_id                                              games  \
# 0  76561198046794970  [{'appid': 205790, 'name': 'Dota 2 Test', 'pla...
# 1  76561198029282766  [{'appid': 23490, 'name': 'Tropico 3 - Steam S...
# 2  76561198044276154  [{'appid': 220, 'name': 'Half-Life 2', 'playti...
# 3  76561198047345390  [{'appid': 40800, 'name': 'Super Meat Boy', 'p...
# 4  76561198065940354  [{'appid': 12210, 'name': 'Grand Theft Auto IV...
#
#                                          valid_games  \
# 0  [{'appid': 570, 'name': 'Dota 2', 'playtime_fo...
# 1  [{'appid': 15700, 'name': 'Oddworld: Abe's Odd...
# 2  [{'appid': 1083500, 'name': 'PlanetSide 2 - Te...
# 3  [{'appid': 238960, 'name': 'Path of Exile', 'p...
# 4  [{'appid': 362960, 'name': 'Tyranny', 'playtim...
#
#                                          train_games
# 0  [{'appid': 214420, 'name': 'Gear Up', 'playtim...
# 1  [{'appid': 23490, 'name': 'Tropico 3 - Steam S...
# 2  [{'appid': 340, 'name': 'Half-Life 2: Lost Coa...
# 3  [{'appid': 40800, 'name': 'Super Meat Boy', 'p...
# 4  [{'appid': 12220, 'name': 'Grand Theft Auto: E...

# %% [markdown]
# Just for fun, let's see which are the most popular games in terms of installs and playtime

# %%
installs = Counter()
playtime = Counter()
for user_id, r in data.set_index('steam_id').iterrows():
    for g in r['games']:
        installs[g['name']] += 1
        playtime[g['name']] += g['playtime_forever'] / 60

# %%
installs.most_common(20)
# Out:
# [('Counter-Strike: Global Offensive', 6846),
#  ('PAYDAY 2', 4689),
#  ('Dota 2 Test', 4673),
#  ('Left 4 Dead 2', 4638),
#  ('Team Fortress 2', 4589),
#  ('Dota 2', 4549),
#  ("Garry's Mod", 3949),
#  ("PLAYERUNKNOWN'S BATTLEGROUNDS", 3878),
#  ('Unturned', 3665),
#  ('Portal 2', 3620),
#  ('Warframe', 3619),
#  ('Borderlands 2', 3271),
#  ('Rocket League', 3238),
#  ('Counter-Strike: Source', 3207),
#  ('Half-Life 2: Lost Coast', 3139),
#  ('Insurgency', 3085),
#  ('Terraria', 3007),
#  ('Portal', 2995),
#  ('Z1 Battle Royale', 2985),
#  ('H1Z1: Test Server', 2985)]

# %%
playtime.most_common(20)
# Out:
# [('Counter-Strike: Global Offensive', 6684950.349999996),
#  ('Dota 2', 5883273.100000011),
#  ('Team Fortress 2', 1155053.0833333305),
#  ("PLAYERUNKNOWN'S BATTLEGROUNDS", 981749.5333333337),
#  ('Rocket League', 703944.0166666653),
#  ('Counter-Strike: Source', 678768.7500000023),
#  ("Garry's Mod", 622710.3666666658),
#  ('Rust', 563462.4333333314),
#  ('Counter-Strike', 500229.6666666664),
#  ('Arma 3', 483356.0833333336),
#  ('Grand Theft Auto V', 482640.99999999895),
#  ('Warframe', 389107.84999999934),
#  ('Path of Exile', 367785.2500000002),
#  ("Tom Clancy's Rainbow Six Siege", 331102.03333333303),
#  ('ARK: Survival Evolved', 275166.39999999997),
#  ('PAYDAY 2', 272460.70000000024),
#  ('Terraria', 223610.6833333334),
#  ('The Elder Scrolls V: Skyrim', 222866.44999999972),
#  ('Left 4 Dead 2', 216298.8166666663),
#  ('Clicker Heroes', 210129.73333333357)]

# %% [markdown]
# For demo purposes, we'll only look at the top 20 games

# %%
MOST_PLAYED_GAMES = [x[0] for x in playtime.most_common(20)]

# %%
playtime = []
for user_id, r in data.set_index('steam_id').iterrows():
    user_playtime = pd.Series([g['playtime_forever'] /60 for g in r['games'] if g['name'] in MOST_PLAYED_GAMES], 
                             index = [g['name'] for g in r['games'] if g['name'] in MOST_PLAYED_GAMES], name=user_id)
    #user_ratings.reindex(index=MOST_PLAYED_GAMES).fillna(0)
    #display(user_ratings)
    if user_playtime.empty: continue
    user_playtime = user_playtime.reindex(MOST_PLAYED_GAMES).fillna(0)
    playtime.append(user_playtime)
# Out:
# <ipython-input-11-62286c695678>:3: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   user_playtime = pd.Series([g['playtime_forever'] /60 for g in r['games'] if g['name'] in MOST_PLAYED_GAMES],

# %%
playtime_matrix = pd.DataFrame(playtime)
playtime_matrix.index.name = "Steam Id"

# %% [markdown]
# # Playtime matrix

# %%
playtime_matrix.iloc[:5].style.set_caption("Playtime matrix").set_precision(4)
# Out:
# <style  type="text/css" >
# </style><table id="T_3793a86c_e02a_11eb_b12d_af41df0e5859" ><caption>Playtime matrix</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Counter-Strike: Global Offensive</th>        <th class="col_heading level0 col1" >Dota 2</th>        <th class="col_heading level0 col2" >Team Fortress 2</th>        <th class="col_heading level0 col3" >PLAYERUNKNOWN'S BATTLEGROUNDS</th>        <th class="col_heading level0 col4" >Rocket League</th>        <th class="col_heading level0 col5" >Counter-Strike: Source</th>        <th class="col_heading level0 col6" >Garry's Mod</th>        <th class="col_heading level0 col7" >Rust</th>        <th class="col_heading level0 col8" >Counter-Strike</th>        <th class="col_heading level0 col9" >Arma 3</th>        <th class="col_heading level0 col10" >Grand Theft Auto V</th>        <th class="col_heading level0 col11" >Warframe</th>        <th class="col_heading level0 col12" >Path of Exile</th>        <th class="col_heading level0 col13" >Tom Clancy's Rainbow Six Siege</th>        <th class="col_heading level0 col14" >ARK: Survival Evolved</th>        <th class="col_heading level0 col15" >PAYDAY 2</th>        <th class="col_heading level0 col16" >Terraria</th>        <th class="col_heading level0 col17" >The Elder Scrolls V: Skyrim</th>        <th class="col_heading level0 col18" >Left 4 Dead 2</th>        <th class="col_heading level0 col19" >Clicker Heroes</th>    </tr>    <tr>        <th class="index_name level0" >Steam Id</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3793a86c_e02a_11eb_b12d_af41df0e5859level0_row0" class="row_heading level0 row0" >76561198046794970</th>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col0" class="data row0 col0" >41.5500</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col1" class="data row0 col1" >1193.9667</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col2" class="data row0 col2" >18.1000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col3" class="data row0 col3" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col4" class="data row0 col4" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col5" class="data row0 col5" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col6" class="data row0 col6" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col7" class="data row0 col7" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col8" class="data row0 col8" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col9" class="data row0 col9" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col10" class="data row0 col10" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col11" class="data row0 col11" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col12" class="data row0 col12" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col13" class="data row0 col13" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col14" class="data row0 col14" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col15" class="data row0 col15" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col16" class="data row0 col16" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col17" class="data row0 col17" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col18" class="data row0 col18" >0.1500</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row0_col19" class="data row0 col19" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_3793a86c_e02a_11eb_b12d_af41df0e5859level0_row1" class="row_heading level0 row1" >76561198029282766</th>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col0" class="data row1 col0" >842.8000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col1" class="data row1 col1" >4809.0667</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col2" class="data row1 col2" >1.9333</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col3" class="data row1 col3" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col4" class="data row1 col4" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col5" class="data row1 col5" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col6" class="data row1 col6" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col7" class="data row1 col7" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col8" class="data row1 col8" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col9" class="data row1 col9" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col10" class="data row1 col10" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col11" class="data row1 col11" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col12" class="data row1 col12" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col13" class="data row1 col13" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col14" class="data row1 col14" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col15" class="data row1 col15" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col16" class="data row1 col16" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col17" class="data row1 col17" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col18" class="data row1 col18" >0.8500</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row1_col19" class="data row1 col19" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_3793a86c_e02a_11eb_b12d_af41df0e5859level0_row2" class="row_heading level0 row2" >76561198044276154</th>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row2_col0" class="data row2 col0" >218.6833</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row2_col1" class="data row2 col1" >1800.8000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row2_col2" class="data row2 col2" >5.4333</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_af41df0e5859row2_col3" class="data row2 col3" >0.0000</td>
#                         <td id="T_3793a86c_e02a_11eb_b12d_a

# %% [markdown]
# # Who is the biggest Dota 2 player?

# %%
playtime_matrix.sort_values("Dota 2", ascending=False)
# Out:
#                    Counter-Strike: Global Offensive        Dota 2  \
# Steam Id
# 76561197970493955                        116.666667  21189.216667
# 76561198140567423                      22069.583333  20025.900000
# 76561198051623299                          8.433333  18149.283333
# 76561198065780626                        172.133333  17559.100000
# 76561198072036324                         98.183333  17535.850000
# ...                                             ...           ...
# 76561198201941911                        656.266667      0.000000
# 76561198205082092                        278.233333      0.000000
# 76561198313506492                        642.283333      0.000000
# 76561198317506140                          0.000000      0.000000
# 76561198071917421                          0.000000      0.000000
#
#                    Team Fortress 2  PLAYERUNKNOWN'S BATTLEGROUNDS  \
# Steam Id
# 76561197970493955         1.516667                      23.550000
# 76561198140567423     19868.116667                   12891.633333
# 76561198051623299         0.000000                       0.000000
# 76561198065780626        10.316667                    2022.000000
# 76561198072036324         0.766667                       0.000000
# ...                            ...                            ...
# 76561198201941911         0.300000                       0.000000
# 76561198205082092         0.000000                       0.000000
# 76561198313506492         0.000000                       0.000000
# 76561198317506140         0.000000                       0.000000
# 76561198071917421         2.200000                       0.000000
#
#                    Rocket League  Counter-Strike: Source  Garry's Mod  \
# Steam Id
# 76561197970493955       0.150000             3316.916667          0.0
# 76561198140567423       0.000000                0.000000          0.0
# 76561198051623299       0.000000                0.000000          0.0
# 76561198065780626      17.483333                0.000000          0.0
# 76561198072036324       0.000000                0.000000          0.0
# ...                          ...                     ...          ...
# 76561198201941911       0.000000                0.000000          0.0
# 76561198205082092       0.000000                0.000000          0.0
# 76561198313506492       0.000000                0.000000          0.0
# 76561198317506140       0.000000                0.000000          0.0
# 76561198071917421       0.000000                0.000000          0.0
#
#                            Rust  Counter-Strike   Arma 3  Grand Theft Auto V  \
# Steam Id
# 76561197970493955      0.000000       19.566667  1425.85            0.000000
# 76561198140567423  13557.600000        0.000000     0.00            0.000000
# 76561198051623299      0.000000        0.000000     0.00            0.000000
# 76561198065780626      7.100000        0.000000     0.00           32.533333
# 76561198072036324      0.000000        0.000000     0.00            0.000000
# ...                         ...             ...      ...                 ...
# 76561198201941911    395.916667        0.000000     0.00            0.000000
# 76561198205082092      0.000000        0.000000     0.00            0.000000
# 76561198313506492      0.000000        0.000000     0.00            0.000000
# 76561198317506140      0.000000        0.000000     0.00            0.000000
# 76561198071917421      0.000000        0.000000     0.00            0.000000
#
#                    Warframe  Path of Exile  Tom Clancy's Rainbow Six Siege  \
# Steam Id
# 76561197970493955  0.000000       0.000000                        0.000000
# 76561198140567423  3.233333       3.050000                        0.000000
# 76561198051623299  0.000000       0.000000                        0.000000
# 76561198065780626  0.000000       0.000000                        9.333333
# 76561198072036324  0.000000      58.966667                        0.000000
# ...                     ...            ...                             ...
# 76561198201941911  0.000000       0.000000                        0.000000
# 76561198205082092  0.000000       0.000000                        0.000000
# 76561198313506492  0.000000       0.000000                        0.000000
# 76561198317506140  0.000000       0.000000                        0.000000
# 76561198071917421  0.000000       0.000000                        0.000000
#
#                    ARK: Survival Evolved  PAYDAY 2  Terraria  \
# Steam Id
# 76561197970493955                    0.0      0.00       0.0
# 76561198140567423                    0.0  19817.85       0.0
# 76561198051623299                    0.0      0.00       0.0
# 76561198065780626                    0.0      0.00       0.0
# 76561198072036324                    0.0      0.00       0.0
# ...                                  ...       ...       ...
# 76561198201941911                    0.0      0.00       0.0
# 76561198205082092                    0.0      0.00       0.0
# 76561198313506492                    0.0      0.00       0.0
# 76561198317506140                    0.0      0.00       0.0
# 76561198071917421                    0.0      0.00       0.0
#
#                    The Elder Scrolls V: Skyrim  Left 4 Dead 2  Clicker Heroes
# Steam Id
# 76561197970493955                     0.933333       9.666667             0.0
# 76561198140567423                     0.000000       0.000000             0.0
# 76561198051623299                     0.000000       0.000000             0.0
# 76561198065780626                     1.166667      16.966667             0.0
# 76561198072036324                     0.000000      41.433333             0.0
# ...                                        ...            ...             ...
# 76561198201941911                     0.000000       1.466667             0.0
# 76561198205082092                     0.000000       0.000000             0.0
# 76561198313506492                     0.000000       0.000000             0.0
# 76561198317506140                     0.000000       0.000000             0.0
# 76561198071917421                     0.000000      92.883333             0.0
#
# [7499 rows x 20 columns]

# %% [markdown]
# # Preference & Confidence Matrix

# %% [markdown]
# The *preference matrix* is simply a binary matrix indicating if the user has played that game or not. We are free to derive the matrix in another manner, but this is the simplest.
#
# The *confidence matrix* reflects our confidence in the preference. I.e. the more a user has played a game, the more he likes it. A simple way to derive it is $ 1+c*P$ where P is the playtime matrix and c is a new hyperparameter.

# %%
C = 40
preference_matrix = (playtime_matrix > 0).astype(int)
confidence_matrix = (1 + playtime_matrix * 40)

# %%
display(preference_matrix.head().style.set_caption("Preference Matrix"))
display(confidence_matrix.head().style.set_caption("Confidence Matrix"))
# Out:
# <style  type="text/css" >
# </style><table id="T_dffaed34_e02b_11eb_b12d_af41df0e5859" ><caption>Preference Matrix</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Counter-Strike: Global Offensive</th>        <th class="col_heading level0 col1" >Dota 2</th>        <th class="col_heading level0 col2" >Team Fortress 2</th>        <th class="col_heading level0 col3" >PLAYERUNKNOWN'S BATTLEGROUNDS</th>        <th class="col_heading level0 col4" >Rocket League</th>        <th class="col_heading level0 col5" >Counter-Strike: Source</th>        <th class="col_heading level0 col6" >Garry's Mod</th>        <th class="col_heading level0 col7" >Rust</th>        <th class="col_heading level0 col8" >Counter-Strike</th>        <th class="col_heading level0 col9" >Arma 3</th>        <th class="col_heading level0 col10" >Grand Theft Auto V</th>        <th class="col_heading level0 col11" >Warframe</th>        <th class="col_heading level0 col12" >Path of Exile</th>        <th class="col_heading level0 col13" >Tom Clancy's Rainbow Six Siege</th>        <th class="col_heading level0 col14" >ARK: Survival Evolved</th>        <th class="col_heading level0 col15" >PAYDAY 2</th>        <th class="col_heading level0 col16" >Terraria</th>        <th class="col_heading level0 col17" >The Elder Scrolls V: Skyrim</th>        <th class="col_heading level0 col18" >Left 4 Dead 2</th>        <th class="col_heading level0 col19" >Clicker Heroes</th>    </tr>    <tr>        <th class="index_name level0" >Steam Id</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dffaed34_e02b_11eb_b12d_af41df0e5859level0_row0" class="row_heading level0 row0" >76561198046794970</th>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col10" class="data row0 col10" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col11" class="data row0 col11" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col13" class="data row0 col13" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col14" class="data row0 col14" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col15" class="data row0 col15" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col16" class="data row0 col16" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col17" class="data row0 col17" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col18" class="data row0 col18" >1</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row0_col19" class="data row0 col19" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_dffaed34_e02b_11eb_b12d_af41df0e5859level0_row1" class="row_heading level0 row1" >76561198029282766</th>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col2" class="data row1 col2" >1</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col8" class="data row1 col8" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col9" class="data row1 col9" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col10" class="data row1 col10" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col11" class="data row1 col11" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col12" class="data row1 col12" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col13" class="data row1 col13" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col14" class="data row1 col14" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col15" class="data row1 col15" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col16" class="data row1 col16" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col17" class="data row1 col17" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col18" class="data row1 col18" >1</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row1_col19" class="data row1 col19" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_dffaed34_e02b_11eb_b12d_af41df0e5859level0_row2" class="row_heading level0 row2" >76561198044276154</th>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row2_col0" class="data row2 col0" >1</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row2_col1" class="data row2 col1" >1</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e5859row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_dffaed34_e02b_11eb_b12d_af41df0e58
# <style  type="text/css" >
# </style><table id="T_dffaed35_e02b_11eb_b12d_af41df0e5859" ><caption>Confidence Matrix</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Counter-Strike: Global Offensive</th>        <th class="col_heading level0 col1" >Dota 2</th>        <th class="col_heading level0 col2" >Team Fortress 2</th>        <th class="col_heading level0 col3" >PLAYERUNKNOWN'S BATTLEGROUNDS</th>        <th class="col_heading level0 col4" >Rocket League</th>        <th class="col_heading level0 col5" >Counter-Strike: Source</th>        <th class="col_heading level0 col6" >Garry's Mod</th>        <th class="col_heading level0 col7" >Rust</th>        <th class="col_heading level0 col8" >Counter-Strike</th>        <th class="col_heading level0 col9" >Arma 3</th>        <th class="col_heading level0 col10" >Grand Theft Auto V</th>        <th class="col_heading level0 col11" >Warframe</th>        <th class="col_heading level0 col12" >Path of Exile</th>        <th class="col_heading level0 col13" >Tom Clancy's Rainbow Six Siege</th>        <th class="col_heading level0 col14" >ARK: Survival Evolved</th>        <th class="col_heading level0 col15" >PAYDAY 2</th>        <th class="col_heading level0 col16" >Terraria</th>        <th class="col_heading level0 col17" >The Elder Scrolls V: Skyrim</th>        <th class="col_heading level0 col18" >Left 4 Dead 2</th>        <th class="col_heading level0 col19" >Clicker Heroes</th>    </tr>    <tr>        <th class="index_name level0" >Steam Id</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dffaed35_e02b_11eb_b12d_af41df0e5859level0_row0" class="row_heading level0 row0" >76561198046794970</th>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col0" class="data row0 col0" >1663.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col1" class="data row0 col1" >47759.666667</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col2" class="data row0 col2" >725.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col3" class="data row0 col3" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col4" class="data row0 col4" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col5" class="data row0 col5" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col6" class="data row0 col6" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col7" class="data row0 col7" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col8" class="data row0 col8" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col9" class="data row0 col9" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col10" class="data row0 col10" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col11" class="data row0 col11" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col12" class="data row0 col12" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col13" class="data row0 col13" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col14" class="data row0 col14" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col15" class="data row0 col15" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col16" class="data row0 col16" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col17" class="data row0 col17" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col18" class="data row0 col18" >7.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row0_col19" class="data row0 col19" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_dffaed35_e02b_11eb_b12d_af41df0e5859level0_row1" class="row_heading level0 row1" >76561198029282766</th>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col0" class="data row1 col0" >33713.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col1" class="data row1 col1" >192363.666667</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col2" class="data row1 col2" >78.333333</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col3" class="data row1 col3" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col4" class="data row1 col4" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col5" class="data row1 col5" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col6" class="data row1 col6" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col7" class="data row1 col7" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col8" class="data row1 col8" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col9" class="data row1 col9" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col10" class="data row1 col10" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col11" class="data row1 col11" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col12" class="data row1 col12" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col13" class="data row1 col13" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col14" class="data row1 col14" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col15" class="data row1 col15" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col16" class="data row1 col16" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col17" class="data row1 col17" >1.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col18" class="data row1 col18" >35.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row1_col19" class="data row1 col19" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_dffaed35_e02b_11eb_b12d_af41df0e5859level0_row2" class="row_heading level0 row2" >76561198044276154</th>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row2_col0" class="data row2 col0" >8748.333333</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row2_col1" class="data row2 col1" >72033.000000</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row2_col2" class="data row2 col2" >218.333333</td>
#                         <td id="T_dffaed35_e02b_11eb_b12d_af41df0e5859row2
